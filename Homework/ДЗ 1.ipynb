# %% [markdown]
# Разбираться будем с датасетом по определению рака у человека. Датасет можно найти тут: https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/data
# Уточнение: M - злокачественная опухоль, B - доброкачественная.

# %% [markdown]
# Заполните блоки кода, в которых написано **TODO**.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Считываем информацию из файла

# %%
df = pd.read_csv(r'C:\Users\art46\Body_bag\NICE/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# **Какое соотношение людей с разными типами опухолей?**
#
# Колонка с диагнозом называется ``diagnosis``

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
B, M = df['diagnosis'].value_counts()
print('Number of Benign: ',B)
print('Number of Malignant : ',M)
print('Number of Benign / Number of Malignant : ', B/M)
# Out:
# Number of Benign:  357
# Number of Malignant :  212
# Number of Benign / Number of Malignant :  1.6839622641509433

# %% [markdown]
# **Какое среднее значение ``area_mean`` у людей с доброкачественной опухолью?**

# %%
df2 = df.loc[df['diagnosis'] == 'B']
df2['area_mean'].mean()
# Out:
# 462.7901960784313

# %% [markdown]
# **Найдите максимальные значения ``perimeter_mean`` у обоих видов опухолей. Найдите отношение максимальных значений с злокачественной опухолью к доброкачественной.**

# %%
df3 = df.loc[df['diagnosis'] == 'M']
df3['perimeter_mean'].max()
# Out:
# 188.5

# %%
df2 = df.loc[df['diagnosis'] == 'B']
df2['perimeter_mean'].max()
# Out:
# 114.6

# %%
df3['perimeter_mean'].max()/df2['perimeter_mean'].max()
# Out:
# 1.6448516579406633

# %% [markdown]
# **Каково максимальное абсолютное значение корреляция между признаками, если не учитывать корреляции со значением 1?**

# %%
df4=df.corr()
df4
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
df4.replace(1, 0, inplace=True)

# %%
df4
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       0.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     0.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      0.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        0.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
df4.max()
# Out:
# id                         0.177742
# radius_mean                0.997855
# texture_mean               0.912045
# perimeter_mean             0.997855
# area_mean                  0.987357
# smoothness_mean            0.805324
# compactness_mean           0.883121
# concavity_mean             0.921391
# concave points_mean        0.921391
# symmetry_mean              0.699826
# fractal_dimension_mean     0.767297
# radius_se                  0.972794
# texture_se                 0.411621
# perimeter_se               0.972794
# area_se                    0.951830
# smoothness_se              0.427374
# compactness_se             0.803269
# concavity_se               0.801268
# concave points_se          0.771804
# symmetry_se                0.449137
# fractal_dimension_se       0.803269
# radius_worst               0.993708
# texture_worst              0.912045
# perimeter_worst            0.993708
# area_worst                 0.984015
# smoothness_worst           0.805324
# ...

# %%
df5=df4.max()
df5.max()
# Out:
# 0.9978552814938109

# %%
df4.max().max()
# Out:
# 0.9978552814938109

# %% [markdown]
# **Найдите процент людей с доброкачественной опухолью и размером этой опухоли менее 400. Также найдите процент людей с доброкачественной опухолью и размером этой опухоли более 800. Выберите верное утверждение.**\
# Колонка с размером опухоли называется `area_mean`

# %%
df6 = df.loc[(df['diagnosis'] == 'B') & (df['area_mean'] < 400)]
df7 = df.loc[(df['diagnosis'] == 'B') & (df['area_mean'] > 800)]

# %%
df.shape[0]
# Out:
# 569

# %%
df6.shape[0]/df.shape[0]
# Out:
# 0.20210896309314588

# %%
df7.shape[0]/df.shape[0]
# Out:
# 0.007029876977152899

# %%
df6
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 21    8510824         B        9.504         12.44           60.34      273.9
# 46   85713702         B        8.196         16.84           51.71      201.9
# 59     858477         B        8.618         11.79           54.34      224.5
# 60     858970         B       10.170         14.88           64.55      311.9
# 61     858981         B        8.598         20.98           54.66      221.8
# ..        ...       ...          ...           ...             ...        ...
# 555    924934         B       10.290         27.61           65.67      321.4
# 556    924964         B       10.160         19.59           64.73      311.7
# 557    925236         B        9.423         27.88           59.26      271.3
# 561    925311         B       11.200         29.37           70.67      386.0
# 568     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
df6['area_mean'].max()
# Out:
# 399.8

# %%
df7['area_mean'].min()
# Out:
# 819.8

# %%
df6['diagnosis'].value_counts()
# Out:
# B    115
# Name: diagnosis, dtype: int64

# %%
df7['diagnosis'].value_counts()
# Out:
# B    4
# Name: diagnosis, dtype: int64
