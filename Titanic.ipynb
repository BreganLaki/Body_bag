# %%
# для раюоты с данными
import pandas as pd

# визуализация
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# для загрузки данных
df = pd.read_csv(r'D:/Pyt/train.csv')

# %%
# для отображения первых 5-ти строк
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.drop(['Ticket', 'PassengerId', 'Name'], axis=1, inplace=True)
df.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df2=df
df2.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df2.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df2.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df2["Embarked"].fillna('S', inplace = True) 
#df2["Embarked"].fillna(df2.'S')
#df.fillna(df.mean())

# %%
df2.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
df2['Age'].fillna(df2['Age'].mean(), inplace = True)

# %%
df2.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
df2.head(20)
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch     Fare Cabin Embarked
# 0          0       3    male  22.000000      1      0   7.2500   NaN        S
# 1          1       1  female  38.000000      1      0  71.2833   C85        C
# 2          1       3  female  26.000000      0      0   7.9250   NaN        S
# 3          1       1  female  35.000000      1      0  53.1000  C123        S
# 4          0       3    male  35.000000      0      0   8.0500   NaN        S
# 5          0       3    male  29.699118      0      0   8.4583   NaN        Q
# 6          0       1    male  54.000000      0      0  51.8625   E46        S
# 7          0       3    male   2.000000      3      1  21.0750   NaN        S
# 8          1       3  female  27.000000      0      2  11.1333   NaN        S
# 9          1       2  female  14.000000      1      0  30.0708   NaN        C
# 10         1       3  female   4.000000      1      1  16.7000    G6        S
# ...

# %%
df2['Survived'].hist()
# Out:
# <AxesSubplot:>

# %%
# гистограмма
ax = sns.countplot(df2['Survived'],label="Count")       
D, S = df2['Survived'].value_counts()
print('Погибли - 0:', D)
print('Выжили - 1:', S)

#y_train = train.Survived
#sns.countplot(y_train, label='Count')
#S, D = y_train.value_counts()
#print('Выжили - 1:', S)
#print('Погибли - 0:', D)
# Out:
# Погибли - 0: 549
# Выжили - 1: 342
# c:\users\art46\ml_practice\mlenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Отделим категориальные признаки от числовых

drop_list = [ 'Survived']

df2.drop(drop_list, axis=1, inplace=True)

# %%
В категориальных признаках есть пол("Sex"). Преобразуем его к числовому перед разделением

# %%
df2.Sex.replace('male', 1, inplace=True)
df2.Sex.replace('female', 0, inplace=True)

# %%
df2.head(20)
# Out:
#     Pclass  Sex        Age  SibSp  Parch     Fare Cabin Embarked
# 0        3    1  22.000000      1      0   7.2500   NaN        S
# 1        1    0  38.000000      1      0  71.2833   C85        C
# 2        3    0  26.000000      0      0   7.9250   NaN        S
# 3        1    0  35.000000      1      0  53.1000  C123        S
# 4        3    1  35.000000      0      0   8.0500   NaN        S
# 5        3    1  29.699118      0      0   8.4583   NaN        Q
# 6        1    1  54.000000      0      0  51.8625   E46        S
# 7        3    1   2.000000      3      1  21.0750   NaN        S
# 8        3    0  27.000000      0      2  11.1333   NaN        S
# 9        2    0  14.000000      1      0  30.0708   NaN        C
# 10       3    0   4.000000      1      1  16.7000    G6        S
# 11       1    0  58.000000      0      0  26.5500  C103        S
# 12       3    1  20.000000      0      0   8.0500   NaN        S
# ...

# %%
#Выберем данные опредленных типов и разделим их
train_cat = df2.select_dtypes(include=['object'], exclude=None)
train_dig = df2.select_dtypes(include=['int64', 'float64'], exclude=None)
train_cat.head(5)
# Out:
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
train_dig.describe().T
# Out:
#         count       mean        std   min      25%        50%   75%       max
# Pclass  891.0   2.308642   0.836071  1.00   2.0000   3.000000   3.0    3.0000
# Sex     891.0   0.647587   0.477990  0.00   0.0000   1.000000   1.0    1.0000
# Age     891.0  29.699118  13.002015  0.42  22.0000  29.699118  35.0   80.0000
# SibSp   891.0   0.523008   1.102743  0.00   0.0000   0.000000   1.0    8.0000
# Parch   891.0   0.381594   0.806057  0.00   0.0000   0.000000   0.0    6.0000
# Fare    891.0  32.204208  49.693429  0.00   7.9104  14.454200  31.0  512.3292

# %%
train_dig.head(5)
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare
# 0       3    1  22.0      1      0   7.2500
# 1       1    0  38.0      1      0  71.2833
# 2       3    0  26.0      0      0   7.9250
# 3       1    0  35.0      1      0  53.1000
# 4       3    1  35.0      0      0   8.0500

# %%
#Есть разброс по максимальным значением: перед визуализацией стандартизируем данные
train_std = (train_dig - train_dig.mean()) / train_dig.std()

# %%
# переменная содержит ответы
y = df['Survived']

train_std = pd.concat([y, train_std], axis=1)
train_std = pd.melt(train_std, id_vars="Survived",
                    var_name="features",
                    value_name='value')
plt.figure(figsize=(14,14))
sns.boxplot(x='features', y='value', hue="Survived", data=train_std)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Pclass'),
#   Text(1, 0, 'Sex'),
#   Text(2, 0, 'Age'),
#   Text(3, 0, 'SibSp'),
#   Text(4, 0, 'Parch'),
#   Text(5, 0, 'Fare')])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train_dig.corr(), vmin=-1, vmax=1, annot=True, linewidths=.5, fmt= '.1f')
# Out:
# <AxesSubplot:>
