# %%
# для раюоты с данными
import pandas as pd
import numpy as np

# визуализация
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:/Pyt/train.csv')

# %%
boxplot = df.boxplot( column = ['Age'], by =['Sex','Survived'])

# %%
sns.boxplot (data=df, x='Survived', y='Age', hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
#ax = sns.countplot(x = "Survived", y = df['Survived'].value_counts(), hue ="Sex", data = df)       

titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", hue= "sex", data=titanic)

# %%
ax = sns.countplot(x="class", hue= "survived", data=titanic)

# %%
ax = sns.countplot(x="class", hue= "survived", data=titanic)

# %%
ax = sns.barplot(x="parch",y="survived", hue= "sex", data=titanic)

# %%
ax = sns.countplot(x="parch", hue= "survived", data=titanic)

# %%
ax = sns.barplot(x="sibsp",y="survived", hue= "sex", data=titanic)

# %%
ax = sns.countplot(x="sibsp", hue= "survived", data=titanic)

# %%
ax = sns.countplot(x="class", hue="who", data=titanic)

# %%
g = sns.catplot(x="class", hue="who", col="survived",

                data=titanic, kind="count",

                height=4, aspect=.7);

# %%
countplot = df.countplot( column = ['Age'], by =['Sex','Survived'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-1d000c28cfe5> in <module>
# ----> 1 countplot = df.countplot( column = ['Age'], by =['Sex','Survived'])
#
# c:\users\art46\ml_practice\mlenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'countplot'
